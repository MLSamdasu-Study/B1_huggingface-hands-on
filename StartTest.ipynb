# %%
import torch
import platform

print(f"OS: {platform.system()} {platform.release()}")
print(f"Processor: {platform.processor()}")
print(f"PyTorch 버전: {torch.__version__}")
print(f"MPS(애플 실리콘 GPU) 빌드 여부: {torch.backends.mps.is_built()}")
print(f"MPS(애플 실리콘 GPU) 사용 가능 여부: {torch.backends.mps.is_available()}")

# 실제 연산 테스트 (GPU 활용)
if torch.backends.mps.is_available():
    device = torch.device("mps")
    x = torch.ones(1, device=device)
    print("M4 Pro GPU에서 연산이 성공적으로 수행되었습니다.")
# Out:
# OS: Darwin 25.3.0
# Processor: arm
# PyTorch 버전: 2.10.0
# MPS(애플 실리콘 GPU) 빌드 여부: True
# MPS(애플 실리콘 GPU) 사용 가능 여부: True
# M4 Pro GPU에서 연산이 성공적으로 수행되었습니다.

# %%
import torch

print(torch.__version__)
print(torch.backends.mps.is_built())
print(torch.backends.mps.is_available())
# Out:
# 2.10.0
# True
# True
